# %%
import tweepy
import json
import re
import arrow
import spacy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pytz import timezone
from dateutil.parser import parse
from textblob import TextBlob
from xml.sax.saxutils import unescape
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

spc = spacy.load('en_core_web_sm')

# %%
trump = pd.read_csv('trump_new.csv')
trump.head()
# Out:
#                     id                      created_at              source  \
# 0  1256037319963967488  Fri May 01 01:46:47 +0000 2020  Twitter for iPhone
# 1  1256037103173017603  Fri May 01 01:45:56 +0000 2020  Twitter for iPhone
# 2  1256025982152200194  Fri May 01 01:01:44 +0000 2020  Twitter for iPhone
# 3  1256024436513411072  Fri May 01 00:55:36 +0000 2020  Twitter for iPhone
# 4  1256024228777857025  Fri May 01 00:54:46 +0000 2020  Twitter for iPhone
#
#    year  month  day  hour  day_of_week  week  is_reply  is_retweet  \
# 0  2020      4   30    21            4    17     False        True
# 1  2020      4   30    21            4    17     False        True
# 2  2020      4   30    21            4    17     False        True
# 3  2020      4   30    20            4    17     False        True
# 4  2020      4   30    20            4    17     False       False
#
#                                        original_text  original_author  \
# 0  The CCP’s Military-Civil Fusion strategy blurs...     SenTomCotton
# 1  Tremendous work by @FreeBeacon \n\nWhile the r...        RichLowry
# 2  Something seems rotten in Flynn's case — my co...  AndrewCMcCarthy
# 3  .@BarackObama is Ultimately Responsible for @F...       BuckSexton
# 4                                                NaN              NaN
#
#                                                 text  favorite_count  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4  “The only thing we got wrong is that it was ev...        156126.0
#
#    retweet_count
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4        38037.0

# %%
def clean_text(df)  :
    # convert to lower case
    # remove hyperlinks / digits / special characters / punctuations / hashtags / accounts
    regex = r'(@[A-Za-z0-9]+)|(&amp;)|([^0-9A-Za-z\'’ \t])|(\w+:\/\/\S+)|([A-Za-z]+[\d@]+[\w@]*|[\d@]+[A-Za-z]+[\w@]*)|(\d+\s)|(\s\d+\s)$'
    df['text_cleaned'] = df['text'].str.lower().apply(lambda t: ' '.join(re.sub(regex, ' ', t).split()))
    # lemmatization
    df['text_cleaned'] = df['text_cleaned'].apply(lambda t: ' '.join([w.lemma_ for w in spc(t) if w.lemma_ != '-PRON-' and '\'' not in w.lemma_ and '’' not in w.lemma_]))
    return df

# %%
# remove retweets without comment
trump_modified = trump[trump['text'].notnull()]
# clean text
trump_modified = clean_text(trump_modified)
# some tweets becomes empty after cleaning because they contains only hyperlinks
trump_modified = trump_modified[trump_modified['text_cleaned'] != '']

trump_modified.head()
# Out:
# /Users/carollam/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/carollam/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                      id                      created_at              source  \
# 4   1256024228777857025  Fri May 01 00:54:46 +0000 2020  Twitter for iPhone
# 6   1256016249169084417  Fri May 01 00:23:04 +0000 2020  Twitter for iPhone
# 7   1256013240896835585  Fri May 01 00:11:06 +0000 2020  Twitter for iPhone
# 8   1256013239487549441  Fri May 01 00:11:06 +0000 2020  Twitter for iPhone
# 10  1255926261068763143  Thu Apr 30 18:25:29 +0000 2020  Twitter for iPhone
#
#     year  month  day  hour  day_of_week  week  is_reply  is_retweet  \
# 4   2020      4   30    20            4    17     False       False
# 6   2020      4   30    20            4    17     False       False
# 7   2020      4   30    20            4    17      True       False
# 8   2020      4   30    20            4    17     False       False
# 10  2020      4   30    14            4    17     False       False
#
#                                         original_text  original_author  \
# 4                                                 NaN              NaN
# 6                                                 NaN              NaN
# 7   Tom Tiffany (@TomTiffanyWI) is a Great Advocat...  realDonaldTrump
# 8                                                 NaN              NaN
# 10                                                NaN              NaN
#
#                                                  text  favorite_count  \
# 4   “The only thing we got wrong is that it was ev...        156126.0
# 6   Vote @MikeGarcia2020 by May 12th! His opponent...         34845.0
# 7   ....He is Strong on Crime, the Border, and Sec...         33328.0
# 8   Tom Tiffany (@TomTiffanyWI) is a Great Advocat...         56133.0
# 10  Over 120 MILLION Economic Impact Payments have...         65073.0
#
#     retweet_count                                       text_cleaned
# 4         38037.0  the only thing get wrong be that be even bad t...
# 6         11170.0  vote by may opponent vote to fire teacher and ...
# 7          8521.0  be strong on crime the border and second amend...
# 8         13626.0  tom tiffany be a great advocate for the incred...
# 10        16955.0  over million economic impact payment have alre...

# %%
def sentiment_textblob(df):
    df['tb_polarity'], df['tb_subjectivity'] = zip(*df['text'].apply(lambda t: TextBlob(t).sentiment))
    df['tb_orientation'] = np.where(df['tb_polarity'] > 0, 'positive', np.where(df['tb_polarity'] < 0, 'negative', 'neutral'))
    df['tb_explanatory'] = np.where(df['tb_subjectivity'] <= 0.5, 'objective', 'subjective')
    return df

def sentiment_vader(df):
    analyser = SentimentIntensityAnalyzer()
    keys = ['neg', 'neu', 'pos', 'compound']
    df['vd_neg'], df['vd_neu'], df['vd_pos'], df['vd_compound'] = zip(*df['text'].apply(lambda t: map(analyser.polarity_scores(t).get, keys)))
    df['vd_orientation'] = np.where(df['vd_compound'] >= 0.05, 'positive', np.where(df['vd_compound'] <= -0.05, 'negative', 'neutral'))
    return df

# %%
# sentiment analysis usting TextBlob
trump_modified = sentiment_textblob(trump_modified)
# sentiment analysis usting Vader
trump_modified = sentiment_vader(trump_modified)

trump_modified.head()
# Out:
#                      id                      created_at              source  \
# 4   1256024228777857025  Fri May 01 00:54:46 +0000 2020  Twitter for iPhone
# 6   1256016249169084417  Fri May 01 00:23:04 +0000 2020  Twitter for iPhone
# 7   1256013240896835585  Fri May 01 00:11:06 +0000 2020  Twitter for iPhone
# 8   1256013239487549441  Fri May 01 00:11:06 +0000 2020  Twitter for iPhone
# 10  1255926261068763143  Thu Apr 30 18:25:29 +0000 2020  Twitter for iPhone
#
#     year  month  day  hour  day_of_week  week  is_reply  ...  \
# 4   2020      4   30    20            4    17     False  ...
# 6   2020      4   30    20            4    17     False  ...
# 7   2020      4   30    20            4    17      True  ...
# 8   2020      4   30    20            4    17     False  ...
# 10  2020      4   30    14            4    17     False  ...
#
#                                          text_cleaned tb_polarity  \
# 4   the only thing get wrong be that be even bad t...   -0.412500
# 6   vote by may opponent vote to fire teacher and ...    1.000000
# 7   be strong on crime the border and second amend...    0.088889
# 8   tom tiffany be a great advocate for the incred...    0.541667
# 10  over million economic impact payment have alre...    0.250000
#
#    tb_subjectivity tb_orientation  tb_explanatory  vd_neg vd_neu  vd_pos  \
# 4         0.825000       negative      subjective   0.373  0.627   0.000
# 6         0.750000       positive      subjective   0.205  0.671   0.123
# 7         0.397222       positive       objective   0.072  0.740   0.189
# 8         0.633333       positive      subjective   0.046  0.640   0.314
# 10        0.400000       positive       objective   0.000  1.000   0.000
#
#     vd_compound vd_orientation
# 4       -0.8786       negative
# 6       -0.4168       negative
# 7        0.6885       positive
# 8        0.9439       positive
# 10       0.0000        neutral
#
# [5 rows x 26 columns]

# %%
trump_modified.to_csv('trump_basic_sentiment.csv', sep=',', encoding='utf-8', index=False)

# %%
t = 'bad!'
TextBlob(t).sentiment
# Out:
# Sentiment(polarity=-0.8749999999999998, subjectivity=0.6666666666666666)
